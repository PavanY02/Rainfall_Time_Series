# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/weatherAUS.csv")

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  datetime64[ns]
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
df.shape
# Out:
# (145460, 23)

# %%
len(df["Location"].unique())
# Out:
# 49

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
# Set the threshold for missing values
threshold = 10000

# Drop columns where the number of NaN values exceeds the threshold
df = df.loc[:, df.isnull().sum() < threshold]

# Check the remaining columns
data = df.columns

columns= []
for i in data:
  if i !='WindDir3pm' and i!="Location" and i!="Date":
    columns.append(i)
print(columns)
# Out:
# ['MinTemp', 'MaxTemp', 'Rainfall', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Temp9am', 'Temp3pm', 'RainToday', 'RainTomorrow']

# %%
print(data)
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
type(data)
# Out:
# pandas.core.indexes.base.Index

# %%
df.isnull().sum()
# Out:
# Date               0
# Location           0
# MinTemp         1485
# MaxTemp         1261
# Rainfall        3261
# WindDir3pm      4228
# WindSpeed9am    1767
# WindSpeed3pm    3062
# Humidity9am     2654
# Humidity3pm     4507
# Temp9am         1767
# Temp3pm         3609
# RainToday       3261
# RainTomorrow    3267
# dtype: int64

# %%
numeric_columns = ['MinTemp', 'MaxTemp', 'Rainfall', 'WindSpeed9am', 'WindSpeed3pm',
                   'Humidity9am', 'Humidity3pm', 'Temp9am', 'Temp3pm']
categorical_columns = ['RainToday', 'RainTomorrow']

for col in numeric_columns:
    df[col].fillna(df[col].rolling(window=10).mean(), inplace=True)

for col in categorical_columns:
    df[col].fillna(method='ffill', inplace=True)  # Or use df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df.head()
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall WindDir3pm  WindSpeed9am  \
# 0 2008-12-01   Albury     13.4     22.9       0.6        WNW          20.0
# 1 2008-12-02   Albury      7.4     25.1       0.0        WSW           4.0
# 2 2008-12-03   Albury     12.9     25.7       0.0        WSW          19.0
# 3 2008-12-04   Albury      9.2     28.0       0.0          E          11.0
# 4 2008-12-05   Albury     17.5     32.3       1.0         NW           7.0
#
#    WindSpeed3pm  Humidity9am  Humidity3pm  Temp9am  Temp3pm RainToday  \
# 0          24.0         71.0         22.0     16.9     21.8        No
# 1          22.0         44.0         25.0     17.2     24.3        No
# 2          26.0         38.0         30.0     21.0     23.2        No
# 3           9.0         45.0         16.0     18.1     26.5        No
# 4          20.0         82.0         33.0     17.8     29.7        No
#
#   RainTomorrow
# 0           No
# 1           No
# 2           No
# 3           No
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
le = LabelEncoder()

# %%
columns =["Location" ,"WindDir3pm",'RainToday', 'RainTomorrow']

for i in columns:
  df[i]= le.fit_transform(df[i])

# %%
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  WindDir3pm  WindSpeed9am  \
# 0 2008-12-01         2     13.4     22.9       0.6          14          20.0
# 1 2008-12-02         2      7.4     25.1       0.0          15           4.0
# 2 2008-12-03         2     12.9     25.7       0.0          15          19.0
# 3 2008-12-04         2      9.2     28.0       0.0           0          11.0
# 4 2008-12-05         2     17.5     32.3       1.0           7           7.0
#
#    WindSpeed3pm  Humidity9am  Humidity3pm  Temp9am  Temp3pm  RainToday  \
# 0          24.0         71.0         22.0     16.9     21.8          0
# 1          22.0         44.0         25.0     17.2     24.3          0
# 2          26.0         38.0         30.0     21.0     23.2          0
# 3           9.0         45.0         16.0     18.1     26.5          0
# 4          20.0         82.0         33.0     17.8     29.7          0
#
#    RainTomorrow
# 0             0
# 1             0
# 2             0
# ...

# %%
df.isnull().sum()
# Out:
# Date               0
# Location           0
# MinTemp         1485
# MaxTemp         1261
# Rainfall        3261
# WindDir3pm         0
# WindSpeed9am    1767
# WindSpeed3pm    3062
# Humidity9am     2654
# Humidity3pm     4507
# Temp9am         1767
# Temp3pm         3609
# RainToday          0
# RainTomorrow       0
# dtype: int64

# %%
columns
# Out:
# ['Location', 'WindDir3pm', 'RainToday', 'RainTomorrow']

# %%
data
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
columns= []
for i in data:
  if df[i].isnull().sum()>0:
    columns.append(i)


print(columns)
# Out:
# ['MinTemp', 'MaxTemp', 'Rainfall', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Temp9am', 'Temp3pm']

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5)
for i in columns:
  df[i] = imputer.fit_transform(df[[i]])

# %%
df.isnull().sum()
# Out:
# Date            0
# Location        0
# MinTemp         0
# MaxTemp         0
# Rainfall        0
# WindDir3pm      0
# WindSpeed9am    0
# WindSpeed3pm    0
# Humidity9am     0
# Humidity3pm     0
# Temp9am         0
# Temp3pm         0
# RainToday       0
# RainTomorrow    0
# dtype: int64

# %%
df.to_csv('Rain_data.csv', index=False)
